# %%
import pandas as pd
from sklearn.cluster import KMeans

import parametrs

# %%
data = pd.read_csv(parametrs.outpitFile,index_col=0)

# %%
data.head()
# Out:
#     c0      c1          c2           c3         c4          c5         c6  \
# 0  0.4  0.0001  909.346310 -5095.471441  16.161917  398.713927  11.728520
# 1  0.4  0.0010  868.044961 -5093.732137  15.125264  398.347052  11.909053
# 2  0.4  0.0100  923.172325 -5095.184888  14.777043  398.299208  12.971807
# 3  0.4  0.1000  310.674511 -5103.908358  14.205556  398.429674  13.011326
# 4  0.4  1.0000  467.521735 -5140.124860  12.834771  397.768908  15.103904
#
#             c7         c8
# 0 -4696.757508  19.320289
# 1 -4695.385083  17.179158
# 2 -4696.885694  18.364852
# 3 -4705.478677  20.961322
# 4 -4742.355954  20.387241

# %%
# data_sort = data.sort_values(by='c1')

# %%
# data = data_sort[:900]

# %%
x = data.c0
y = data.c1
data = data.drop(['c0','c1'],axis=1)

# %%
len(data)
# Out:
# 1944

# %%
data = data.fillna(0)

# %%
data.head()
# Out:
#            c2           c3         c4          c5         c6           c7  \
# 0  909.346310 -5095.471441  16.161917  398.713927  11.728520 -4696.757508
# 1  868.044961 -5093.732137  15.125264  398.347052  11.909053 -4695.385083
# 2  923.172325 -5095.184888  14.777043  398.299208  12.971807 -4696.885694
# 3  310.674511 -5103.908358  14.205556  398.429674  13.011326 -4705.478677
# 4  467.521735 -5140.124860  12.834771  397.768908  15.103904 -4742.355954
#
#           c8
# 0  19.320289
# 1  17.179158
# 2  18.364852
# 3  20.961322
# 4  20.387241

# %%
kmeans = KMeans(n_clusters=3, random_state=42).fit_predict(data)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y,c=kmeans)
plt.ylim()
# Out:
# (-0.515071600441501, 10.5151716004415)

# %%
plt.scatter(x,y,c=kmeans)
plt.ylim(.0001,.01)
# Out:
# (0.0001, 0.01)

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
testModelAnswers = AgglomerativeClustering(n_clusters=3).fit_predict(data)
plt.scatter(x,y,c=testModelAnswers)

# %%
# Попробуем обработать данные - вычтим среднее, поделим на отклонение
data = (data - data.mean())/data.std()

# %%
data = data.fillna(0)

# %%
kmeans = KMeans(n_clusters=3).fit_predict(data)
plt.scatter(x,y,c=kmeans)

# %%
plt.scatter(x,y,c=kmeans)
plt.ylim(.0001,.01)
# Out:
# (0.0001, 0.01)
