# %%
import pandas as pd
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('data.csv',index_col=0)

# %%
data
# Out:
#     c0   c1         c2         c3         c4        c5  c6  c7         c8  \
# 0  0.5  0.0 -4942.8965  490.70939 -4452.1871  0.965902 NaN NaN -4959.7257
# 1  0.5  0.1 -4977.7619  506.66209 -4471.0998  0.992883 NaN NaN -4948.6875
# 2  0.7  0.0 -4942.8965  490.70939 -4452.1871  0.965902 NaN NaN -4959.7257
# 3  0.7  0.1 -4977.7619  506.66209 -4471.0998  0.992883 NaN NaN -4948.6875
# 4  0.9  0.0 -4942.8965  490.70939 -4452.1871  0.965902 NaN NaN -4959.7257
# 5  0.9  0.1 -4977.7619  506.66209 -4471.0998  0.992883 NaN NaN -4948.6875
# 6  1.1  0.0 -4942.8965  490.70939 -4452.1871  0.965902 NaN NaN -4959.7257
# 7  1.1  0.1 -4977.7619  506.66209 -4471.0998  0.992883 NaN NaN -4948.6875
#
#           c9 ...   c55     c56  c57  c58     c59  c60  c61     c62  c63  c64
# 0  529.71635 ...   0.0  0.1625  0.0  0.0  0.1875  0.0  0.0  0.2125  0.0  0.0
# 1  492.15704 ...   0.0  0.1625  0.0  0.0  0.1875  0.0  0.0  0.2125  0.0  0.0
# 2  529.71635 ...   0.0  0.1625  0.0  0.0  0.1875  0.0  0.0  0.2125  0.0  0.0
# 3  492.15704 ...   0.0  0.1625  0.0  0.0  0.1875  0.0  0.0  0.2125  0.0  0.0
# 4  529.71635 ...   0.0  0.1625  0.0  0.0  0.1875  0.0  0.0  0.2125  0.0  0.0
# 5  492.15704 ...   0.0  0.1625  0.0  0.0  0.1875  0.0  0.0  0.2125  0.0  0.0
# 6  529.71635 ...   0.0  0.1625  0.0  0.0  0.1875  0.0  0.0  0.2125  0.0  0.0
# 7  492.15704 ...   0.0  0.1625  0.0  0.0  0.1875  0.0  0.0  0.2125  0.0  0.0
#
# [8 rows x 65 columns]

# %%
x = data.c0
y = data.c1
data = data.drop(['c0','c1'],axis=1)

# %%
data = data.fillna(0)

# %%
kmeans = KMeans(n_clusters=3, random_state=42).fit_predict(data)
kmeans
# Out:
# array([0, 1, 0, 1, 0, 1, 0, 1])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y,s=100,c=kmeans)
