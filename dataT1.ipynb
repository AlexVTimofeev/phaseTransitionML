# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_0_0001 = pd.read_table(
    'processedData/temp1.00000.press0.00010.rdf',skiprows=[0,1,2,3,4],
    delimiter=' ',names=['Row','c_1[1]','c_1[2]','c_1[3]'],index_col='Row')
data_0_001 = pd.read_table(
    'processedData/temp1.00000.press0.00100.rdf',skiprows=[0,1,2,3,4],
    delimiter=' ',names=['Row','c_1[1]','c_1[2]','c_1[3]'],index_col='Row')
data_0_01 = pd.read_table(
    'processedData/temp1.00000.press0.01000.rdf',skiprows=[0,1,2,3,4],
    delimiter=' ',names=['Row','c_1[1]','c_1[2]','c_1[3]'],index_col='Row')
data_0_1 = pd.read_table(
    'processedData/temp1.00000.press0.10000.rdf',skiprows=[0,1,2,3,4],
    delimiter=' ',names=['Row','c_1[1]','c_1[2]','c_1[3]'],index_col='Row')
data_10 = pd.read_table(
    'processedData/temp1.press10.rdf',skiprows=[0,1,2,3,4],
    delimiter=' ',names=['Row','c_1[1]','c_1[2]','c_1[3]'],index_col='Row')

# %%
fig = plt.figure()
fig.add_subplot()
data_0_0001['c_1[2]'].plot(title = 'T = 1 P = 0.0001')
fig = plt.figure()
data_0_001['c_1[2]'].plot(title = 'T = 1 P = 0.001')
fig = plt.figure()
data_0_01['c_1[2]'].plot(title = 'T = 1 P = 0.01')
fig = plt.figure()
data_0_1['c_1[2]'].plot(title = 'T = 1 P = 0.1')
fig = plt.figure()
data_10['c_1[2]'].plot(title = 'T = 1 P = 10')
